# %% [markdown]
# # Shhh... it's a secret!
#
# Secrets on Colab are a great way to store sensitive information that are used within the notebook. You want to showcase your work and share your notebooks, but no, you don't want to share your secrets with everyone on the internet.
#
# So, what do you do? You use secrets, of course.
#
# Read on, to see how to store secrets and use it in your colab notebook.
#
# This notebook is part of [this blog](https://blog.prashu.com/using-secrets-with-colab-enterprise-10e44bff87d8).

# %% [markdown]
# ## Step 1
# a. Open the secrets panel on the left and create a new secret.
#
# b. Add a new secret, by clicking on add, adding the name for the secret, and then the secret itself. Don't forget to mark the secret as accessible for the current notebook, so that you can use it.
#
# ![Screenshot 2024-07-27 at 9.11.17 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## Step 2
# Import the secret into code by referencing the name.

# %%
# import userdata module and access the secret
from google.colab import userdata
secret = userdata.get('secret_secret')

# %% [markdown]
# ## Step 3
#
# Use it as you deem fit, but be careful, you can still output the secret in plain text.

# %%
# bad bad... don't do this!
print(secret)
# Out:
# shhh... this is secret!

# %%
# just a dummy function
def use_the_secret_to_do_stuff(name: str, secret: str):
  print(f"You are authorised, {name}!")
  pass

# call a function that needs the secret
use_the_secret_to_do_stuff("Bob", secret)
# Out:
# You are authorised, Bob!
